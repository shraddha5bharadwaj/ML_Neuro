# %%
import sys
from google.colab import drive
drive.mount('/content/gdrive/')
sys.path.append('/content/gdrive/MyDrive/MLNBD/Project')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
pip install pynwb
# Out:
# Collecting pynwb
#   Downloading pynwb-2.8.2-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: h5py>=2.10 in /usr/local/lib/python3.10/dist-packages (from pynwb) (3.11.0)
# Collecting hdmf>=3.14.3 (from pynwb)
#   Downloading hdmf-3.14.5-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from pynwb) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from pynwb) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pynwb) (2.8.2)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from hdmf>=3.14.3->pynwb) (4.23.0)
# Collecting ruamel-yaml>=0.16 (from hdmf>=3.14.3->pynwb)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.10/dist-packages (from hdmf>=3.14.3->pynwb) (1.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->pynwb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->pynwb) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pynwb) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (0.20.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel-yaml>=0.16->hdmf>=3.14.3->pynwb)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Downloading pynwb-2.8.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.0 MB/s eta 0:00:00
# Downloading hdmf-3.14.5-py3-none-any.whl (338 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.5/338.5 kB 20.8 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 9.3 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 29.7 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel-yaml, hdmf, pynwb
# Successfully installed hdmf-3.14.5 pynwb-2.8.2 ruamel-yaml-0.18.6 ruamel.yaml.clib-0.2.8

# %%
from pynwb import NWBHDF5IO

# Path to your NWB file
nwb_file_path = '/content/gdrive/MyDrive/MLNBD/Project/sub-Jenkins_ses-small_desc-train_behavior+ecephys (3).nwb'

# Open the NWB file
with NWBHDF5IO(nwb_file_path, 'r') as io:
    nwbfile = io.read()

# Access the metadata or data in the NWB file
print(nwbfile.fields)  # This will give you an overview of the contents

# For example, you can access time series data:
if nwbfile.fields:
    for key, val in nwbfile.fields.items():
        print(f"Acquisition key: {key}, value: {val}")
# Out:
# {'session_description': 'Data from monkey Jenkins performing center-out delayed reaching task. This file contains trials from the full session on 2009-09-28 that can be used for training models for the Neural Latents Benchmark.', 'identifier': '76ff7eba-0b93-11ec-a90d-3da92aaa0e59', 'session_start_time': datetime.datetime(2009, 9, 28, 0, 0, tzinfo=tzoffset(None, -25200)), 'timestamps_reference_time': datetime.datetime(2009, 9, 28, 0, 0, tzinfo=tzoffset(None, -25200)), 'file_create_date': [datetime.datetime(2021, 9, 1, 22, 14, 12, 620183, tzinfo=tzoffset(None, -14400))], 'experimenter': ('Mark M. Churchland', 'Matthew T. Kaufman'), 'related_publications': ('https://doi.org/10.1016/j.neuron.2010.09.015',), 'keywords': <StrDataset for Closed HDF5 dataset>, 'processing': {'behavior': behavior pynwb.base.ProcessingModule at 0x139210371257712
# Fields:
#   data_interfaces: {
#     cursor_pos <class 'pynwb.behavior.SpatialSeries'>,
#     eye_pos <class 'pynwb.behavior.SpatialSeries'>,
#     hand_pos <class 'pynwb.behavior.SpatialSeries'>,
#     hand_vel <class 'pynwb.base.TimeSeries'>
#   }
#   description: Processed behavioral data
# }, 'electrodes': electrodes hdmf.common.table.DynamicTable at 0x139210371262416
# Fields:
#   colnames: ['x' 'y' 'z' 'imp' 'location' 'filtering' 'group' 'group_name']
#   columns: (
#     x <class 'hdmf.common.table.VectorData'>,
#     y <class 'hdmf.common.table.VectorData'>,
#     z <class 'hdmf.common.table.VectorData'>,
#     imp <class 'hdmf.common.table.VectorData'>,
#     location <class 'hdmf.common.table.VectorData'>,
#     filtering <class 'hdmf.common.table.VectorData'>,
#     group <class 'hdmf.common.table.VectorData'>,
#     group_name <class 'hdmf.common.table.VectorData'>
#   )
#   description: metadata about extracellular electrodes
# , 'electrode_groups': {'electrode_group_M1': electrode_group_M1 pynwb.ecephys.ElectrodeGroup at 0x139210371267888
# Fields:
#   description: Electrodes in an implanted Utah array in M1
#   device: electrode_array_M1 pynwb.device.Device at 0x139210371267264
# Fields:
#   description: 96-electrode Utah array in M1
#   manufacturer: Blackrock Microsystems
#
#   location: Primary motor cortex
# , 'electrode_group_PMd': electrode_group_PMd pynwb.ecephys.ElectrodeGroup at 0x139210371265920
# Fields:
#   description: Electrodes in implanted Utah Array in PMd
#   device: electrode_array_PMd pynwb.device.Device at 0x139210371267552
# Fields:
#   description: 96-electrode Utah array in PMd
#   manufacturer: Blackrock Microsystems
#
#   location: Dorsal premotor cortex
# }, 'devices': {'electrode_array_M1': electrode_array_M1 pynwb.device.Device at 0x139210371267264
# Fields:
#   description: 96-electrode Utah array in M1
#   manufacturer: Blackrock Microsystems
# , 'electrode_array_PMd': electrode_array_PMd pynwb.device.Device at 0x139210371267552
# Fields:
#   description: 96-electrode Utah array in PMd
#   manufacturer: Blackrock Microsystems
# }, 'intervals': {'trials': trials pynwb.epoch.TimeIntervals at 0x139210371267696
# Fields:
#   colnames: ['start_time' 'stop_time' 'trial_type' 'trial_version' 'maze_id' 'success'
#  'target_on_time' 'go_cue_time' 'move_onset_time' 'rt' 'delay'
#  'num_targets' 'target_pos' 'num_barriers' 'barrier_pos' 'active_target'
#  'split']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     trial_type <class 'hdmf.common.table.VectorData'>,
#     trial_version <class 'hdmf.common.table.VectorData'>,
#     maze_id <class 'hdmf.common.table.VectorData'>,
#     success <class 'hdmf.common.table.VectorData'>,
#     target_on_time <class 'hdmf.common.table.VectorData'>,
#     go_cue_time <class 'hdmf.common.table.VectorData'>,
#     move_onset_time <class 'hdmf.common.table.VectorData'>,
#     rt <class 'hdmf.common.table.VectorData'>,
#     delay <class 'hdmf.common.table.VectorData'>,
#     num_targets <class 'hdmf.common.table.VectorData'>,
#     target_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     target_pos <class 'hdmf.common.table.VectorData'>,
#     num_barriers <class 'hdmf.common.table.VectorData'>,
#     barrier_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     barrier_pos <class 'hdmf.common.table.VectorData'>,
#     active_target <class 'hdmf.common.table.VectorData'>,
#     split <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental trials
# }, 'subject': subject pynwb.file.Subject at 0x139210371264432
# Fields:
#   sex: M
#   species: Macaca mulatta
#   subject_id: Jenkins
# , 'trials': trials pynwb.epoch.TimeIntervals at 0x139210371267696
# Fields:
#   colnames: ['start_time' 'stop_time' 'trial_type' 'trial_version' 'maze_id' 'success'
#  'target_on_time' 'go_cue_time' 'move_onset_time' 'rt' 'delay'
#  'num_targets' 'target_pos' 'num_barriers' 'barrier_pos' 'active_target'
#  'split']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     trial_type <class 'hdmf.common.table.VectorData'>,
#     trial_version <class 'hdmf.common.table.VectorData'>,
#     maze_id <class 'hdmf.common.table.VectorData'>,
#     success <class 'hdmf.common.table.VectorData'>,
#     target_on_time <class 'hdmf.common.table.VectorData'>,
#     go_cue_time <class 'hdmf.common.table.VectorData'>,
#     move_onset_time <class 'hdmf.common.table.VectorData'>,
#     rt <class 'hdmf.common.table.VectorData'>,
#     delay <class 'hdmf.common.table.VectorData'>,
#     num_targets <class 'hdmf.common.table.VectorData'>,
#     target_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     target_pos <class 'hdmf.common.table.VectorData'>,
#     num_barriers <class 'hdmf.common.table.VectorData'>,
#     barrier_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     barrier_pos <class 'hdmf.common.table.VectorData'>,
#     active_target <class 'hdmf.common.table.VectorData'>,
#     split <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental trials
# , 'units': units pynwb.misc.Units at 0x139210371259632
# Fields:
#   colnames: ['heldout' 'spike_times' 'obs_intervals' 'electrodes']
#   columns: (
#     heldout <class 'hdmf.common.table.VectorData'>,
#     spike_times_index <class 'hdmf.common.table.VectorIndex'>,
#     spike_times <class 'hdmf.common.table.VectorData'>,
#     obs_intervals_index <class 'hdmf.common.table.VectorIndex'>,
#     obs_intervals <class 'hdmf.common.table.VectorData'>,
#     electrodes_index <class 'hdmf.common.table.VectorIndex'>,
#     electrodes <class 'hdmf.common.table.DynamicTableRegion'>
#   )
#   description: data on spiking units
#   waveform_unit: volts
# , 'experiment_description': 'Center-out delayed reaching task with maze barriers.', 'session_id': 'small', 'lab': 'Shenoy', 'institution': 'Stanford University'}
# Acquisition key: session_description, value: Data from monkey Jenkins performing center-out delayed reaching task. This file contains trials from the full session on 2009-09-28 that can be used for training models for the Neural Latents Benchmark.
# Acquisition key: identifier, value: 76ff7eba-0b93-11ec-a90d-3da92aaa0e59
# Acquisition key: session_start_time, value: 2009-09-28 00:00:00-07:00
# Acquisition key: timestamps_reference_time, value: 2009-09-28 00:00:00-07:00
# Acquisition key: file_create_date, value: [datetime.datetime(2021, 9, 1, 22, 14, 12, 620183, tzinfo=tzoffset(None, -14400))]
# Acquisition key: experimenter, value: ('Mark M. Churchland', 'Matthew T. Kaufman')
# Acquisition key: related_publications, value: ('https://doi.org/10.1016/j.neuron.2010.09.015',)
# Acquisition key: keywords, value: <StrDataset for Closed HDF5 dataset>
# Acquisition key: processing, value: {'behavior': behavior pynwb.base.ProcessingModule at 0x139210371257712
# Fields:
#   data_interfaces: {
#     cursor_pos <class 'pynwb.behavior.SpatialSeries'>,
#     eye_pos <class 'pynwb.behavior.SpatialSeries'>,
#     hand_pos <class 'pynwb.behavior.SpatialSeries'>,
#     hand_vel <class 'pynwb.base.TimeSeries'>
#   }
#   description: Processed behavioral data
# }
# Acquisition key: electrodes, value: electrodes hdmf.common.table.DynamicTable at 0x139210371262416
# Fields:
#   colnames: ['x' 'y' 'z' 'imp' 'location' 'filtering' 'group' 'group_name']
#   columns: (
#     x <class 'hdmf.common.table.VectorData'>,
#     y <class 'hdmf.common.table.VectorData'>,
#     z <class 'hdmf.common.table.VectorData'>,
#     imp <class 'hdmf.common.table.VectorData'>,
#     location <class 'hdmf.common.table.VectorData'>,
#     filtering <class 'hdmf.common.table.VectorData'>,
#     group <class 'hdmf.common.table.VectorData'>,
#     group_name <class 'hdmf.common.table.VectorData'>
#   )
#   description: metadata about extracellular electrodes
#
# Acquisition key: electrode_groups, value: {'electrode_group_M1': electrode_group_M1 pynwb.ecephys.ElectrodeGroup at 0x139210371267888
# Fields:
#   description: Electrodes in an implanted Utah array in M1
#   device: electrode_array_M1 pynwb.device.Device at 0x139210371267264
# Fields:
#   description: 96-electrode Utah array in M1
#   manufacturer: Blackrock Microsystems
#
#   location: Primary motor cortex
# , 'electrode_group_PMd': electrode_group_PMd pynwb.ecephys.ElectrodeGroup at 0x139210371265920
# Fields:
#   description: Electrodes in implanted Utah Array in PMd
#   device: electrode_array_PMd pynwb.device.Device at 0x139210371267552
# Fields:
#   description: 96-electrode Utah array in PMd
#   manufacturer: Blackrock Microsystems
#
#   location: Dorsal premotor cortex
# }
# Acquisition key: devices, value: {'electrode_array_M1': electrode_array_M1 pynwb.device.Device at 0x139210371267264
# Fields:
#   description: 96-electrode Utah array in M1
#   manufacturer: Blackrock Microsystems
# , 'electrode_array_PMd': electrode_array_PMd pynwb.device.Device at 0x139210371267552
# Fields:
#   description: 96-electrode Utah array in PMd
#   manufacturer: Blackrock Microsystems
# }
# Acquisition key: intervals, value: {'trials': trials pynwb.epoch.TimeIntervals at 0x139210371267696
# Fields:
#   colnames: ['start_time' 'stop_time' 'trial_type' 'trial_version' 'maze_id' 'success'
#  'target_on_time' 'go_cue_time' 'move_onset_time' 'rt' 'delay'
#  'num_targets' 'target_pos' 'num_barriers' 'barrier_pos' 'active_target'
#  'split']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     trial_type <class 'hdmf.common.table.VectorData'>,
#     trial_version <class 'hdmf.common.table.VectorData'>,
#     maze_id <class 'hdmf.common.table.VectorData'>,
#     success <class 'hdmf.common.table.VectorData'>,
#     target_on_time <class 'hdmf.common.table.VectorData'>,
#     go_cue_time <class 'hdmf.common.table.VectorData'>,
#     move_onset_time <class 'hdmf.common.table.VectorData'>,
#     rt <class 'hdmf.common.table.VectorData'>,
#     delay <class 'hdmf.common.table.VectorData'>,
#     num_targets <class 'hdmf.common.table.VectorData'>,
#     target_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     target_pos <class 'hdmf.common.table.VectorData'>,
#     num_barriers <class 'hdmf.common.table.VectorData'>,
#     barrier_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     barrier_pos <class 'hdmf.common.table.VectorData'>,
#     active_target <class 'hdmf.common.table.VectorData'>,
#     split <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental trials
# }
# Acquisition key: subject, value: subject pynwb.file.Subject at 0x139210371264432
# Fields:
#   sex: M
#   species: Macaca mulatta
#   subject_id: Jenkins
#
# Acquisition key: trials, value: trials pynwb.epoch.TimeIntervals at 0x139210371267696
# Fields:
#   colnames: ['start_time' 'stop_time' 'trial_type' 'trial_version' 'maze_id' 'success'
#  'target_on_time' 'go_cue_time' 'move_onset_time' 'rt' 'delay'
#  'num_targets' 'target_pos' 'num_barriers' 'barrier_pos' 'active_target'
#  'split']
#   columns: (
#     start_time <class 'hdmf.common.table.VectorData'>,
#     stop_time <class 'hdmf.common.table.VectorData'>,
#     trial_type <class 'hdmf.common.table.VectorData'>,
#     trial_version <class 'hdmf.common.table.VectorData'>,
#     maze_id <class 'hdmf.common.table.VectorData'>,
#     success <class 'hdmf.common.table.VectorData'>,
#     target_on_time <class 'hdmf.common.table.VectorData'>,
#     go_cue_time <class 'hdmf.common.table.VectorData'>,
#     move_onset_time <class 'hdmf.common.table.VectorData'>,
#     rt <class 'hdmf.common.table.VectorData'>,
#     delay <class 'hdmf.common.table.VectorData'>,
#     num_targets <class 'hdmf.common.table.VectorData'>,
#     target_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     target_pos <class 'hdmf.common.table.VectorData'>,
#     num_barriers <class 'hdmf.common.table.VectorData'>,
#     barrier_pos_index <class 'hdmf.common.table.VectorIndex'>,
#     barrier_pos <class 'hdmf.common.table.VectorData'>,
#     active_target <class 'hdmf.common.table.VectorData'>,
#     split <class 'hdmf.common.table.VectorData'>
#   )
#   description: experimental trials
#
# Acquisition key: units, value: units pynwb.misc.Units at 0x139210371259632
# Fields:
#   colnames: ['heldout' 'spike_times' 'obs_intervals' 'electrodes']
#   columns: (
#     heldout <class 'hdmf.common.table.VectorData'>,
#     spike_times_index <class 'hdmf.common.table.VectorIndex'>,
#     spike_times <class 'hdmf.common.table.VectorData'>,
#     obs_intervals_index <class 'hdmf.common.table.VectorIndex'>,
#     obs_intervals <class 'hdmf.common.table.VectorData'>,
#     electrodes_index <class 'hdmf.common.table.VectorIndex'>,
#     electrodes <class 'hdmf.common.table.DynamicTableRegion'>
#   )
#   description: data on spiking units
#   waveform_unit: volts
#
# Acquisition key: experiment_description, value: Center-out delayed reaching task with maze barriers.
# Acquisition key: session_id, value: small
# Acquisition key: lab, value: Shenoy
# Acquisition key: institution, value: Stanford University

# %%
from pynwb import NWBHDF5IO

# Path to your NWB file
# nwb_file_path = 'path/to/your/file.nwb'

# Open the NWB file
with NWBHDF5IO(nwb_file_path, 'r') as io:
    nwbfile = io.read()

    # Accessing behavior data (like cursor position, eye position, etc.)
    behavior_module = nwbfile.processing.get('behavior')

    if behavior_module is not None:
        # Access cursor position data
        cursor_pos = behavior_module.get_data_interface('cursor_pos')
        if cursor_pos:
            cursor_data = cursor_pos.data[:]
            cursor_time = cursor_pos.timestamps[:]
            print("Cursor Position Data:", cursor_data)
            print("Cursor Position Timestamps:", cursor_time)

        # Access hand position data
        hand_pos = behavior_module.get_data_interface('hand_pos')
        if hand_pos:
            hand_data = hand_pos.data[:]
            hand_time = hand_pos.timestamps[:]
            print("Hand Position Data:", hand_data)
            print("Hand Position Timestamps:", hand_time)

    # Accessing electrodes data
    electrodes_table = nwbfile.electrodes
    if electrodes_table is not None:
        # For example, extract the 'x', 'y', and 'z' coordinates
        electrode_x = electrodes_table['x'][:]
        electrode_y = electrodes_table['y'][:]
        electrode_z = electrodes_table['z'][:]

        print("Electrode X coordinates:", electrode_x)
        print("Electrode Y coordinates:", electrode_y)
        print("Electrode Z coordinates:", electrode_z)
# Out:
# Cursor Position Data: [[  -4.1           3.        ]
#  [  -4.07350645    3.00747767]
#  [  -4.04892157    3.01283136]
#  ...
#  [-116.43615482  -78.91893529]
#  [-116.46684173  -78.90706292]
#  [-116.5         -78.9       ]]
# Cursor Position Timestamps: [0.00000e+00 1.00000e-03 2.00000e-03 ... 2.93663e+02 2.93664e+02
#  2.93665e+02]
# Hand Position Data: [[  -4.06939146  -31.88889289]
#  [  -4.06694074  -31.90072274]
#  [  -4.0645211   -31.91298044]
#  ...
#  [-116.52004028 -113.88330479]
#  [-116.52171585 -113.88007067]
#  [-116.52314573 -113.87750746]]
# Hand Position Timestamps: [0.00000e+00 1.00000e-03 2.00000e-03 ... 2.93663e+02 2.93664e+02
#  2.93665e+02]
# Electrode X coordinates: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
# Electrode Y coordinates: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
# Electrode Z coordinates: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
