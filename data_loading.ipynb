# %%
import sys
from google.colab import drive
drive.mount('/content/gdrive/')
sys.path.append('/content/gdrive/MyDrive/MLNBD/Project')
import numpy as np

import pandas as pd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !pip install pynwb
# Out:
# Requirement already satisfied: pynwb in /usr/local/lib/python3.10/dist-packages (2.8.2)
# Requirement already satisfied: h5py>=2.10 in /usr/local/lib/python3.10/dist-packages (from pynwb) (3.12.1)
# Requirement already satisfied: hdmf>=3.14.3 in /usr/local/lib/python3.10/dist-packages (from pynwb) (3.14.5)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from pynwb) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from pynwb) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pynwb) (2.8.2)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from hdmf>=3.14.3->pynwb) (4.23.0)
# Requirement already satisfied: ruamel-yaml>=0.16 in /usr/local/lib/python3.10/dist-packages (from hdmf>=3.14.3->pynwb) (0.18.6)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.10/dist-packages (from hdmf>=3.14.3->pynwb) (1.13.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->pynwb) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->pynwb) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pynwb) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6.0->hdmf>=3.14.3->pynwb) (0.20.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel-yaml>=0.16->hdmf>=3.14.3->pynwb) (0.2.12)

# %%
from pynwb import NWBHDF5IO

# Open the NWB file
file_path = '/content/gdrive/MyDrive/MLNBD/Project/sub-Jenkins_ses-small_desc-train_behavior+ecephys (3).nwb'
# file_path = "/content/gdrive/MyDrive/MLNBD/Project/sub-Jenkins_ses-small_desc-test_ecephys (3).nwb"
with NWBHDF5IO(file_path, 'r') as io:
    nwbfile = io.read()  # Read the NWB file content

    # Explore the general structure of the NWB file
    print(nwbfile)  # Print summary of the contents

    # Access specific data, like acquisition data, e.g., ElectricalSeries data
    # for acquisition_name, data in nwbfile.acquisition.items():
    #     print(f"Acquisition Name: {acquisition_name}")
    #     print(data)  # Print details about the acquisition
# Out:
# /usr/local/lib/python3.10/dist-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.5.0 because version 1.8.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /usr/local/lib/python3.10/dist-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.4.0 because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /usr/local/lib/python3.10/dist-packages/hdmf/spec/namespace.py:535: UserWarning: Ignoring cached namespace 'hdmf-experimental' version 0.1.0 because version 0.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# root pynwb.file.NWBFile at 0x137392709748624
# Fields:
#   devices: {
#     electrode_array_M1 <class 'pynwb.device.Device'>,
#     electrode_array_PMd <class 'pynwb.device.Device'>
#   }
#   electrode_groups: {
#     electrode_group_M1 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     electrode_group_PMd <class 'pynwb.ecephys.ElectrodeGroup'>
#   }
#   electrodes: electrodes <class 'hdmf.common.table.DynamicTable'>
#   experiment_description: Center-out delayed reaching task with maze barriers.
#   experimenter: ['Mark M. Churchland' 'Matthew T. Kaufman']
#   file_create_date: [datetime.datetime(2021, 9, 1, 22, 14, 12, 620183, tzinfo=tzoffset(None, -14400))]
#   identifier: 76ff7eba-0b93-11ec-a90d-3da92aaa0e59
#   institution: Stanford University
#   intervals: {
#     trials <class 'pynwb.epoch.TimeIntervals'>
#   }
#   keywords: <StrDataset for HDF5 dataset "keywords": shape (5,), type "|O">
#   lab: Shenoy
#   processing: {
#     behavior <class 'pynwb.base.ProcessingModule'>
#   }
#   related_publications: ['https://doi.org/10.1016/j.neuron.2010.09.015']
#   session_description: Data from monkey Jenkins performing center-out delayed reaching task. This file contains trials from the full session on 2009-09-28 that can be used for training models for the Neural Latents Benchmark.
#   session_id: small
#   session_start_time: 2009-09-28 00:00:00-07:00
#   subject: subject pynwb.file.Subject at 0x137392709838800
# Fields:
#   sex: M
#   species: Macaca mulatta
#   subject_id: Jenkins
#
#   timestamps_reference_time: 2009-09-28 00:00:00-07:00
#   trials: trials <class 'pynwb.epoch.TimeIntervals'>
#   units: units <class 'pynwb.misc.Units'>

# %%
from pynwb import NWBHDF5IO

# Path to your NWB file
file_path = '/content/gdrive/MyDrive/MLNBD/Project/sub-Jenkins_ses-small_desc-train_behavior+ecephys (3).nwb'


# Open the NWB file
with NWBHDF5IO(file_path, 'r') as io:
    nwbfile = io.read()

    # Get basic metadata
    print("Session Description:", nwbfile.session_description)
    print("Session ID:", nwbfile.session_id)
    print("Session Start Time:", nwbfile.session_start_time)
    print("Experiment Description:", nwbfile.experiment_description)
    print("Experimenter(s):", nwbfile.experimenter)
    print("Institution:", nwbfile.institution)
    print("Lab:", nwbfile.lab)
    print("File Creation Date:", nwbfile.file_create_date)
    print("Identifier:", nwbfile.identifier)
    print("Related Publications:", nwbfile.related_publications)
    print("Keywords:", nwbfile.keywords)

    # Subject Information
    # subject = nwbfile.subject
    # if subject:
    #     print("Subject Information:")
    #     print("  Sex:", subject.sex)
    #     print("  Species:", subject.species)
    #     print("  Subject ID:", subject.subject_id)

    # # Devices
    # print("\nDevices:")
    # for name, device in nwbfile.devices.items():
    #     print(f"  {name}: {device}")

    # # Electrode Groups
    # print("\nElectrode Groups:")
    # for name, group in nwbfile.electrode_groups.items():
    #     print(f"  {name}: {group}")

    # # Electrodes table
    # electrodes = nwbfile.electrodes
    # print("\nElectrodes Table:")
    # if electrodes:
    #     df = electrodes.to_dataframe() # Convert to pandas DataFrame for easier viewing
    #     df.to_csv('/content/gdrive/MyDrive/MLNBD/ML_Neuro/Electrode_table.csv', index=False)

    # # Trials
    # trials = nwbfile.trials
    # print("\nTrials:")
    # if trials:
    #     print(trials.to_dataframe())  # Convert to pandas DataFrame
    #     df = trials.to_dataframe() # Convert to pandas DataFrame

    #     df.to_csv('/content/gdrive/MyDrive/MLNBD/ML_Neuro/Trials.csv', index=False)

    # Units
    # units = nwbfile.units
    # print("\nUnits:")
    # if units:
    #     print(units.to_dataframe())  # Convert to pandas DataFrame
    #     df = units.to_dataframe() # Convert to pandas DataFrame

    #     df.to_csv('/content/gdrive/MyDrive/MLNBD/ML_Neuro/Units.csv', index=False)

    # # Time Intervals (e.g., trials or epochs)
    # print("\nIntervals:")
    # for name, interval in nwbfile.intervals.items():
    #     print(f"  {name}:")
    #     print(interval.to_dataframe())  # Convert to pandas DataFrame
    #     df = interval.to_dataframe() # Convert to pandas DataFrame

    #     df.to_csv(f'/content/gdrive/MyDrive/MLNBD/ML_Neuro/Trials/{name}.csv', index=False)

    # Processing modules (e.g., behavior)
    print("\nProcessing Modules:")
    for name, module in nwbfile.processing.items():
        print(f"  Module Name: {name}")
        behavior_module = nwbfile.processing.get('behavior')
        for data_interface_name, data_interface in module.data_interfaces.items():
            print(f"    Data Interface: {data_interface_name}")
            if hasattr(data_interface, 'to_dataframe'):
                print(data_interface.to_dataframe())  # Convert to DataFrame if possible
                # df = data_interface.to_dataframe() # Convert to pandas DataFrame
                # df.to_csv(f'/content/gdrive/MyDrive/MLNBD/ML_Neuro/{name}_{data_interface_name}.csv', index=False)


                cursor_pos = nwbfile.processing['behavior'].data_interfaces[data_interface_name]

                # Read data and timestamps
                data = cursor_pos.data[:]           # Cursor position data (x, y) coordinates
                timestamps = cursor_pos.timestamps[:]  # Corresponding timestamps

                # Print sample data
                print("Data Shapeasaa:", data.shape)  # Should output (287710, 2)
                print("Timestamps Shape:", timestamps.shape)  # Should output (287710,)
                print("First 10 Rows of Data:\n", data[:10])  # Display first 10 rows of data
                print("First 10 Timestamps:\n", timestamps[:10])

            else:
                print("wswsw",data_interface)
                interface = nwbfile.processing['behavior'].data_interfaces[data_interface_name]

                # Read data and timestamps
                data = interface.data[:]           # Cursor position data (x, y) coordinates
                timestamps = interface.timestamps[:]  # Corresponding timestamps
                print(type(data))
                # Print sample data
                print("Data Shapeasaa:", data.shape)  # Should output (287710, 2)
                print("Timestamps Shape:", timestamps.shape)  # Should output (287710,)
                print("First 10 Rows of Data:\n", data[:10])  # Display first 10 rows of data
                print("First 10 Timestamps:\n", timestamps[:10])

                np.save("/content/gdrive/MyDrive/MLNBD/ML_Neuro/behaviour_data/"+data_interface_name+'data.npy', data)
                np.save("/content/gdrive/MyDrive/MLNBD/ML_Neuro/behaviour_data/"+data_interface_name+'timestamp.npy', timestamps)


    # # Acquisition data
    # print("\nAcquisition Data:")
    # for name, acquisition in nwbfile.acquisition.items():
    #     print(f"  {name}: {acquisition}")
    #     if hasattr(acquisition, 'data'):
    #         data = acquisition.data[:]
    #         print(f"    Data Shape: {data.shape}")
    #         print("    Data:", data)

    # # Stimulus data
    # print("\nStimulus Data:")
    # for name, stimulus in nwbfile.stimulus.items():
    #     print(f"  {name}: {stimulus}")
    #     if hasattr(stimulus, 'data'):
    #         data = stimulus.data[:]
    #         print(f"    Data Shape: {data.shape}")
    #         print("    Data:", data)
# Out:
# Session Description: Data from monkey Jenkins performing center-out delayed reaching task. This file contains trials from the full session on 2009-09-28 that can be used for training models for the Neural Latents Benchmark.
# Session ID: small
# Session Start Time: 2009-09-28 00:00:00-07:00
# Experiment Description: Center-out delayed reaching task with maze barriers.
# Experimenter(s): ('Mark M. Churchland', 'Matthew T. Kaufman')
# Institution: Stanford University
# Lab: Shenoy
# File Creation Date: [datetime.datetime(2021, 9, 1, 22, 14, 12, 620183, tzinfo=tzoffset(None, -14400))]
# Identifier: 76ff7eba-0b93-11ec-a90d-3da92aaa0e59
# Related Publications: ('https://doi.org/10.1016/j.neuron.2010.09.015',)
# Keywords: <StrDataset for HDF5 dataset "keywords": shape (5,), type "|O">
#
# Processing Modules:
#   Module Name: behavior
#     Data Interface: cursor_pos
# wswsw cursor_pos pynwb.behavior.SpatialSeries at 0x137392709751648
# Fields:
#   comments: columns=[x,y]
#   conversion: 0.001
#   data: <HDF5 dataset "data": shape (287710, 2), type "<f8">
#   description: Cursor position in mm. First column x, second column y
#   interval: 1
#   offset: 0.0
#   reference_frame: (0, 0) is screen center
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (287710,), type "<f8">
#   timestamps_unit: seconds
#   unit: meters
#
# <class 'numpy.ndarray'>
# Data Shapeasaa: (287710, 2)
# Timestamps Shape: (287710,)
# First 10 Rows of Data:
#  [[-4.1         3.        ]
#  [-4.07350645  3.00747767]
#  [-4.04892157  3.01283136]
#  [-4.02782931  3.0141464 ]
#  [-4.01134637  3.01006292]
#  [-4.          3.        ]
#  [-3.99315545  2.98027996]
#  [-3.99086671  2.95749284]
#  [-3.99214892  2.93467865]
#  [-3.99567857  2.91475739]]
# First 10 Timestamps:
#  [0.    0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009]
#     Data Interface: eye_pos
# wswsw eye_pos pynwb.behavior.SpatialSeries at 0x137392709752944
# Fields:
#   comments: columns=[x,y]
#   conversion: 0.001
#   data: <HDF5 dataset "data": shape (287710, 2), type "<f8">
#   description: Monkey eye position in mm. First column x, second column y
#   interval: 1
#   offset: 0.0
#   reference_frame: (0, 0) is screen center
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (287710,), type "<f8">
#   timestamps_unit: seconds
#   unit: meters
#
# <class 'numpy.ndarray'>
# Data Shapeasaa: (287710, 2)
# Timestamps Shape: (287710,)
# First 10 Rows of Data:
#  [[-11.9  -5.6]
#  [-10.1  -5.9]
#  [-10.2  -4.1]
#  [-10.   -5.6]
#  [-10.5  -8.8]
#  [-10.2  -5.5]
#  [-10.3  -6.4]
#  [-10.4  -5.7]
#  [-10.1  -5.4]
#  [-10.7  -5.9]]
# First 10 Timestamps:
#  [0.    0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009]
#     Data Interface: hand_pos
# wswsw hand_pos pynwb.behavior.SpatialSeries at 0x137392709760048
# Fields:
#   comments: columns=[x,y]
#   conversion: 0.001
#   data: <HDF5 dataset "data": shape (287710, 2), type "<f8">
#   description: Monkey hand position in mm. First column x, second column y
#   interval: 1
#   offset: 0.0
#   reference_frame: (0, 0) is screen center
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (287710,), type "<f8">
#   timestamps_unit: seconds
#   unit: meters
#
# <class 'numpy.ndarray'>
# Data Shapeasaa: (287710, 2)
# Timestamps Shape: (287710,)
# First 10 Rows of Data:
#  [[ -4.06939146 -31.88889289]
#  [ -4.06694074 -31.90072274]
#  [ -4.0645211  -31.91298044]
#  [ -4.0621682  -31.92550114]
#  [ -4.05982209 -31.93811223]
#  [ -4.05750185 -31.95082761]
#  [ -4.05533624 -31.96355149]
#  [ -4.0531941  -31.97622613]
#  [ -4.05118168 -31.9888123 ]
#  [ -4.04944275 -32.00130926]]
# First 10 Timestamps:
#  [0.    0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009]
#     Data Interface: hand_vel
# wswsw hand_vel pynwb.base.TimeSeries at 0x137392709498816
# Fields:
#   comments: columns=[x,y]
#   conversion: 0.001
#   data: <HDF5 dataset "data": shape (287710, 2), type "<f8">
#   description: Monkey hand velocity in mm/s, calculated from monkey hand position. First column x, second column y
#   interval: 1
#   offset: 0.0
#   resolution: -1.0
#   timestamps: <HDF5 dataset "timestamps": shape (287710,), type "<f8">
#   timestamps_unit: seconds
#   unit: m/s
#
# <class 'numpy.ndarray'>
# Data Shapeasaa: (287710, 2)
# Timestamps Shape: (287710,)
# First 10 Rows of Data:
#  [[  2.45072011 -11.82985185]
#  [  2.43518325 -12.04377785]
#  [  2.38626918 -12.38919835]
#  [  2.34950084 -12.56589177]
#  [  2.33317659 -12.66323671]
#  [  2.24292988 -12.7196338 ]
#  [  2.15387381 -12.69925789]
#  [  2.07727776 -12.63040353]
#  [  1.87567545 -12.54156803]
#  [  1.60996587 -12.39511298]]
# First 10 Timestamps:
#  [0.    0.001 0.002 0.003 0.004 0.005 0.006 0.007 0.008 0.009]

# %%
import pynwb
from pynwb import NWBHDF5IO

# Path to the NWB file
# file_path = 'path_to_your_file.nwb'
file_path = '/content/gdrive/MyDrive/MLNBD/Project/sub-Jenkins_ses-small_desc-train_behavior+ecephys (3).nwb'

# Open the NWB file in read mode
with NWBHDF5IO(file_path, 'r') as io:
    # Read the NWB file into a NWBFile object
    nwb_file = io.read()

    # Access general metadata
    print("Experiment Description:", nwb_file.experiment_description)
    print("Experimenters:", nwb_file.experimenter)
    print("Session Start Time:", nwb_file.session_start_time)
    print("Session Description:", nwb_file.session_description)

    # Access devices
    devices = nwb_file.devices
    for device_name, device in devices.items():
        print(f"Device: {device_name}, Type: {device.__class__.__name__}")

    # Access electrode groups
    electrode_groups = nwb_file.electrode_groups
    for group_name, group in electrode_groups.items():
        print(f"Electrode Group: {group_name}, Type: {group.__class__.__name__}")

    # Access electrodes (DynamicTable)
    electrodes = nwb_file.electrodes
    print(f"Number of electrodes: {len(electrodes)}")

    # Access trials (TimeIntervals)
    trials = nwb_file.intervals['trials']
    print(f"Number of trials: {len(trials)}")

    # Access units (Units)
    units = nwb_file.units
    print(f"Number of units: {len(units)}")

    # Access subject info
    subject = nwb_file.subject
    print(f"Subject ID: {subject.subject_id}, Species: {subject.species}, Sex: {subject.sex}")

    # Access related publications
    publications = nwb_file.related_publications
    print("Related Publications:", publications)
# Out:
# Experiment Description: Center-out delayed reaching task with maze barriers.
# Experimenters: ('Mark M. Churchland', 'Matthew T. Kaufman')
# Session Start Time: 2009-09-28 00:00:00-07:00
# Session Description: Data from monkey Jenkins performing center-out delayed reaching task. This file contains trials from the full session on 2009-09-28 that can be used for training models for the Neural Latents Benchmark.
# Device: electrode_array_M1, Type: Device
# Device: electrode_array_PMd, Type: Device
# Electrode Group: electrode_group_M1, Type: ElectrodeGroup
# Electrode Group: electrode_group_PMd, Type: ElectrodeGroup
# Number of electrodes: 192
# Number of trials: 100
# Number of units: 142
# Subject ID: Jenkins, Species: Macaca mulatta, Sex: M
# Related Publications: ('https://doi.org/10.1016/j.neuron.2010.09.015',)

# %%
from pynwb import NWBHDF5IO

# Path to your NWB file
# nwb_file_path = 'path/to/your/file.nwb'

# Open the NWB file
with NWBHDF5IO(nwb_file_path, 'r') as io:
    nwbfile = io.read()

    # Accessing behavior data (like cursor position, eye position, etc.)
    behavior_module = nwbfile.processing.get('behavior')

    if behavior_module is not None:
        # Access cursor position data
        cursor_pos = behavior_module.get_data_interface('cursor_pos')
        if cursor_pos:
            cursor_data = cursor_pos.data[:]
            cursor_time = cursor_pos.timestamps[:]
            print("Cursor Position Data:", cursor_data)
            print("Cursor Position Timestamps:", cursor_time)

        # Access hand position data
        hand_pos = behavior_module.get_data_interface('hand_pos')
        if hand_pos:
            hand_data = hand_pos.data[:]
            hand_time = hand_pos.timestamps[:]
            print("Hand Position Data:", hand_data)
            print("Hand Position Timestamps:", hand_time)

    # Accessing electrodes data
    electrodes_table = nwbfile.electrodes
    if electrodes_table is not None:
        # For example, extract the 'x', 'y', and 'z' coordinates
        electrode_x = electrodes_table['x'][:]
        electrode_y = electrodes_table['y'][:]
        electrode_z = electrodes_table['z'][:]

        print("Electrode X coordinates:", electrode_x)
        print("Electrode Y coordinates:", electrode_y)
        print("Electrode Z coordinates:", electrode_z)
# Out:
# Cursor Position Data: [[  -4.1           3.        ]
#  [  -4.07350645    3.00747767]
#  [  -4.04892157    3.01283136]
#  ...
#  [-116.43615482  -78.91893529]
#  [-116.46684173  -78.90706292]
#  [-116.5         -78.9       ]]
# Cursor Position Timestamps: [0.00000e+00 1.00000e-03 2.00000e-03 ... 2.93663e+02 2.93664e+02
#  2.93665e+02]
# Hand Position Data: [[  -4.06939146  -31.88889289]
#  [  -4.06694074  -31.90072274]
#  [  -4.0645211   -31.91298044]
#  ...
#  [-116.52004028 -113.88330479]
#  [-116.52171585 -113.88007067]
#  [-116.52314573 -113.87750746]]
# Hand Position Timestamps: [0.00000e+00 1.00000e-03 2.00000e-03 ... 2.93663e+02 2.93664e+02
#  2.93665e+02]
# Electrode X coordinates: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
# Electrode Y coordinates: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
# Electrode Z coordinates: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
